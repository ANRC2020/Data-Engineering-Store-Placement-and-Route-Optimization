# %% [markdown]
# So now that we have our positional data, we want to figure out where to open brick-and-motar locations for AGM. Our approach for identifying good locations to open is to open stores near the most central locations in each county.
#
# The point of this notebook is demostrating how Neo4j can be used to find the most central points taking into account the distance from other locations and potentially the expected population at each. Furthermore, once we know these locations we will need to identify the closest BART station and plot a course from the station to the central points.

# %% [markdown]
# First we will import the data on BART Stations and locations into NOSQL tables.

# %%
# Run this to install necessary packages and restart the kernel for osmnx import error to be resolved

# !pip install geopandas
# !pip install folium
# !pip install geopy
# !pip install taxicab
# !pip install osmnx==1.9.1
# !pip install --upgrade osmnx matplotlib numpy

# %%
import neo4j
import pandas as pd
from IPython.display import display

import warnings

warnings.simplefilter("ignore", category=FutureWarning)

import geopandas as gpd
import math
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
from folium.features import DivIcon
import requests 
import numpy as np
import random
from geopy.geocoders import Nominatim
from IPython.display import Image, IFrame 
from IPython.core.display import HTML 
from pandas import json_normalize
# %matplotlib inline
import osmnx as ox
from osmnx import plot_route_folium
import networkx as nx
import matplotlib
import matplotlib as plt
import taxicab as tc
from IPython.display import clear_output
import csv
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/conda/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /opt/conda/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
locations_df = pd.read_csv("locations_project.csv")

locations_df.head()
# Out:
#                                                 name     county  \
# 0                               Fr Dental Laboratory  San Mateo
# 1                         Pacifica Spindrift Players  San Mateo
# 2                   Pulgas Ridge Open Space Preserve  San Mateo
# 3                                              GoPro  San Mateo
# 4  Forensic Laboratory of San Mateo Co. Sheriff's...  San Mateo
#
#                 coordinates  esti. pop.          nearest node one  \
# 0  (37.485814, -122.238715)        2651  (37.478609, -122.291883)
# 1  (37.592423, -122.489007)         306  (37.459552, -122.429672)
# 2  (37.478609, -122.291883)        1745  (37.485814, -122.238715)
# 3  (37.534532, -122.331311)         494   (37.513253, -122.33258)
# 4   (37.513253, -122.33258)        2878  (37.534532, -122.331311)
#
#              nearest node 2            nearest node 3    distance 1  \
# 0  (37.444031, -122.161216)  (37.491431, -122.228803)   5629.155382
# 1  (37.462736, -122.429145)  (37.633669, -122.397713)  21589.095445
# 2   (37.513253, -122.33258)  (37.491431, -122.228803)   5606.499382
# 3  (37.535644, -122.334809)  (37.545193, -122.306168)   4426.607702
# 4  (37.535644, -122.334809)  (37.545193, -122.306168)   4426.607702
#
#      distance 2    distance 3
# 0   7902.135854   1246.209503
# 1  21269.789077  15705.573372
# 2   8101.156342   6747.760637
# 3   2830.915494   5630.481052
# 4   3428.965861   5643.734418

# %%
bart_stations_df = pd.read_csv("BART_Stations_project.csv")

bart_stations_df.head()
# Out:
#                                   name         county  \
# 0  West Dublin/Pleasanton BART Station   Contra Costa
# 1           Montgomery St BART Station  San Francisco
# 2             San Antonio BART Station        Alameda
# 3                 Fremont BART Station        Alameda
# 4             Santana Row BART Station    Santa Clara
#
#                 coordinates  esti. pop.
# 0  (37.699709, -121.928243)         428
# 1  (37.788862, -122.402116)        1812
# 2  (37.788309, -122.245649)        1489
# 3  (37.557451, -121.976611)        1813
# 4  (37.323154, -121.948811)         965

# %% [markdown]
# Dimensions of our data:

# %%
print(f"locations_df: {locations_df.shape}")
print(f"bart_stations_df: {bart_stations_df.shape}")
# Out:
# locations_df: (100, 10)
# bart_stations_df: (18, 4)

# %% [markdown]
# Split the locations df into 2 dataframes, one defining each node and the other describing relations within set of nodes

# %%
def get_nodes(county):

    # Split locations into two dataframes

    nodes = locations_df[['name', "county", "coordinates", "esti. pop." ]].loc[locations_df['county'] == county]
    node_relations = locations_df[["coordinates", "nearest node one", "nearest node 2", "nearest node 3", "distance 1", "distance 2", "distance 3"]].loc[locations_df['county'] == county]
    
    return nodes, node_relations

nodes, node_relations = get_nodes('Santa Clara')

# %%
nodes
# Out:
#                                                  name       county  \
# 60                               Victory Martial Arts  Santa Clara
# 61                       Multitest Electronic Systems  Santa Clara
# 62  SYNQMINE Business Intelligence & Outsource CFO...  Santa Clara
# 63                                         Lucas Hall  Santa Clara
# 64                           Benefit Brow Bar At Ulta  Santa Clara
# 65                                     Hot Java To Go  Santa Clara
# 66                            Intel Santa Clara - SC2  Santa Clara
# 67                                    Miller Networks  Santa Clara
# 68            Skip's Tire & Auto Center - Cottle Road  Santa Clara
# 69                                   Club Hitachi Gym  Santa Clara
# 70                          Crystalline Sound Healing  Santa Clara
# 71                               OCZ Technology Group  Santa Clara
# 72            Children's Discovery Museum of San Jose  Santa Clara
# 73                                        Bloom Fresh  Santa Clara
# 74         Watermark Medical Animation & Illustration  Santa Clara
# 75                                     SAL Classrooms  Santa Clara
# 76                  Caring Neighbors Enterprises Inc.  Santa Clara
# 77  Kinetic Wellness Center, Dr George Chiropracti...  Santa Clara
# 78                        Peak Technology Enterprises  Santa Clara
# 79                             Primetime Martial Arts  Santa Clara
#
#                  coordinates  esti. pop.
# 60  (37.244966, -121.889866)         432
# 61   (37.377044, -121.95603)        1913
# 62  (37.402767, -121.891175)        2059
# 63  (37.351107, -121.939733)         436
# 64  (37.249065, -121.801793)         894
# 65  (37.214525, -121.727838)         744
# 66  (37.375963, -121.975229)        2033
# 67  (37.116172, -121.640973)        1344
# 68  (37.244915, -121.804446)        1389
# 69  (37.373002, -121.947864)         391
# 70  (37.246705, -122.041108)        2806
# 71  (37.237705, -121.783374)        2414
# 72   (37.32658, -121.891846)         713
# 73  (37.329666, -121.843218)        1034
# 74  (37.379838, -121.994338)         517
# 75  (37.330916, -121.884955)         893
# 76  (37.449312, -121.905431)        2139
# 77  (37.228165, -121.778364)         407
# 78  (37.230286, -121.776686)         592
# 79  (37.236254, -121.805053)        1829

# %%
def augment_node_relations(nodes, node_relations):

    # We can map each Lat. long. pair key 

    HT = {}

    for i in range(nodes.shape[0]):
        HT[nodes.iloc[i]['coordinates']] = nodes.iloc[i]['name']

    # Next we need to replace the coordinates in the node relations table

    origin_node = []
    nn_one = []
    nn_two = []
    nn_three = []

    for i in range(node_relations.shape[0]):
        origin_node.append(HT[node_relations.iloc[i]['coordinates']])
        nn_one.append(HT[node_relations.iloc[i]['nearest node one']])
        nn_two.append(HT[node_relations.iloc[i]['nearest node 2']])
        nn_three.append(HT[node_relations.iloc[i]['nearest node 3']])

    node_relations['origin_node'] = origin_node
    node_relations['Nearest Node 1 Name'] = nn_one
    node_relations['Nearest Node 2 Name'] = nn_two
    node_relations['Nearest Node 3 Name'] = nn_three

    return node_relations

node_relations = augment_node_relations(nodes, node_relations)

# %%
def generate_query(nodes, node_relations):
    
    # We will need to store the original and new names
    
    transformed_names = {}
    
    # We want to create the table for Neo4j

    create_query = "CREATE\n"

    for i in range(nodes.shape[0]):

        loc_name = nodes.iloc[i]['name'].replace(':', '').replace('&', '').replace(',', '').replace('.', '_').replace('-', '').replace("'", "").replace("#","").replace("/","").replace(' ', '')

        try:

            if type(int(loc_name[0])) == int:
                create_query += f"\t(l_{loc_name.lower()}:POINT" + " {" + f"name:'l_{loc_name}', "  + f" population: {nodes.iloc[i]['esti. pop.']}" + "}),\n" # + f"latitude: {nodes.iloc[i]['coordinates'].strip('()').split(', ')[0]}," + f" longitude: {nodes.iloc[i]['coordinates'].strip('()').split(', ')[1]},"
                transformed_names[f"l_{loc_name}"] = nodes.iloc[i]['name']
                
        except:
            create_query += f"\t({loc_name.lower()}:POINT" + " {" + f"name:'{loc_name}', "  + f" population: {nodes.iloc[i]['esti. pop.']}" + "}),\n" # + f"latitude: {nodes.iloc[i]['coordinates'].strip('()').split(', ')[0]}," + f" longitude: {nodes.iloc[i]['coordinates'].strip('()').split(', ')[1]},"
            transformed_names[loc_name] = nodes.iloc[i]['name']
            
    for i in range(node_relations.shape[0]):

        origin_name = node_relations.iloc[i]['origin_node'].replace(':', '').replace('&', '').replace(',', '').replace('.', '_').replace('-', '').replace("'", "").replace("#","").replace("/","").replace(' ', '')

        nn_1_name = node_relations.iloc[i]['Nearest Node 1 Name'].replace(':', '').replace('&', '').replace(',', '').replace('.', '_').replace('-', '').replace("'", "").replace("#","").replace("/","").replace(' ', '')
        nn_2_name = node_relations.iloc[i]['Nearest Node 2 Name'].replace(':', '').replace('&', '').replace(',', '').replace('.', '_').replace('-', '').replace("'", "").replace("#","").replace("/","").replace(' ', '')
        nn_3_name = node_relations.iloc[i]['Nearest Node 3 Name'].replace(':', '').replace('&', '').replace(',', '').replace('.', '_').replace('-', '').replace("'", "").replace("#","").replace("/","").replace(' ', '')

        try:
            if type(int(origin_name[0])) == int:
                origin_name = "l_" + origin_name

        except:
            pass

        try:
            if type(int(nn_1_name[0])) == int:
                nn_1_name = "l_" + nn_1_name

        except:
            pass

        try:
            if type(int(nn_2_name[0])) == int:
                nn_2_name = "l_" + nn_2_name

        except:
            pass

        try:
            if type(int(nn_3_name[0])) == int:
                nn_3_name = "l_" + nn_3_name

        except:
            pass

        create_query += f"\t({origin_name.lower()})" + "-[:distance {" + f"distance: {node_relations.iloc[i]['distance 1']}" + "}]-> " + f"({nn_1_name.lower()}),\n"
        create_query += f"\t({origin_name.lower()})" + "-[:distance {" + f"distance: {node_relations.iloc[i]['distance 2']}" + "}]-> " + f"({nn_2_name.lower()}),\n"
        create_query += f"\t({origin_name.lower()})" + "-[:distance {" + f"distance: {node_relations.iloc[i]['distance 3']}" + "}]-> " + f"({nn_3_name.lower()})"
    #     (seattle)-[:TRACK {track_miles: 798}]->(berkeley),
        if i < node_relations.shape[0] - 1:
            create_query += ",\n"

    return create_query, transformed_names

create_query, transformed_names = generate_query(nodes, node_relations)

# %% [markdown]
# Web server interface at https://xxxx:7473
# Username: neo4j
# Password: ucb_mids_w205

# %% [markdown]
# The next step is to initialize Neo4j for our notebook (We are using code from Lab 9)

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))

# %%
session = driver.session(database="neo4j")

# %%
def my_neo4j_wipe_out_database():
    "wipe out database by deleting all nodes and relationships"
    
    query = "match (node)-[relationship]->() delete node, relationship"
    session.run(query)
    
    query = "match (node) delete node"
    session.run(query)

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
def my_neo4j_nodes_relationships():
    "print all the nodes and relationships"
   
    print("-------------------------")
    print("  Nodes:")
    print("-------------------------")
    
    query = """
        match (n) 
        return n.name as node_name, labels(n) as labels
        order by n.name
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_nodes = df.shape[0]
    
    display(df)
    
    print("-------------------------")
    print("  Relationships:")
    print("-------------------------")
    
    query = """
        match (n1)-[r]->(n2) 
        return n1.name as node_name_1, labels(n1) as node_1_labels, 
            type(r) as relationship_type, n2.name as node_name_2, labels(n2) as node_2_labels
        order by node_name_1, node_name_2
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_relationships = df.shape[0]
    
    display(df)
    
    density = (2 * number_relationships) / (number_nodes * (number_nodes - 1))
    
    print("-------------------------")
    print("  Density:", f'{density:.1f}')
    print("-------------------------")

# %%
def my_create_connected_graph(create_query):
    "create the connected graph"
    
    my_neo4j_wipe_out_database()

    session.run(create_query)

# %%
my_create_connected_graph(create_query)

# %%
my_neo4j_nodes_relationships()
# Out:
# -------------------------
#   Nodes:
# -------------------------
#                                             node_name   labels
# 0                                BenefitBrowBarAtUlta  [POINT]
# 1                                          BloomFresh  [POINT]
# 2                      CaringNeighborsEnterprisesInc_  [POINT]
# 3                   ChildrensDiscoveryMuseumofSanJose  [POINT]
# 4                                      ClubHitachiGym  [POINT]
# 5                             CrystallineSoundHealing  [POINT]
# 6                                         HotJavaToGo  [POINT]
# 7                                  IntelSantaClaraSC2  [POINT]
# 8   KineticWellnessCenterDrGeorgeChiropracticCorpo...  [POINT]
# 9                                           LucasHall  [POINT]
# 10                                     MillerNetworks  [POINT]
# 11                         MultitestElectronicSystems  [POINT]
# 12                                 OCZTechnologyGroup  [POINT]
# 13                          PeakTechnologyEnterprises  [POINT]
# 14                               PrimetimeMartialArts  [POINT]
# 15                                      SALClassrooms  [POINT]
# 16   SYNQMINEBusinessIntelligenceOutsourceCFOServices  [POINT]
# 17                      SkipsTireAutoCenterCottleRoad  [POINT]
# 18                                 VictoryMartialArts  [POINT]
# 19              WatermarkMedicalAnimationIllustration  [POINT]
# -------------------------
#   Relationships:
# -------------------------
#                                           node_name_1 node_1_labels  \
# 0                                BenefitBrowBarAtUlta       [POINT]
# 1                                BenefitBrowBarAtUlta       [POINT]
# 2                                BenefitBrowBarAtUlta       [POINT]
# 3                                          BloomFresh       [POINT]
# 4                                          BloomFresh       [POINT]
# 5                                          BloomFresh       [POINT]
# 6                      CaringNeighborsEnterprisesInc_       [POINT]
# 7                      CaringNeighborsEnterprisesInc_       [POINT]
# 8                      CaringNeighborsEnterprisesInc_       [POINT]
# 9                   ChildrensDiscoveryMuseumofSanJose       [POINT]
# 10                  ChildrensDiscoveryMuseumofSanJose       [POINT]
# 11                  ChildrensDiscoveryMuseumofSanJose       [POINT]
# 12                                     ClubHitachiGym       [POINT]
# 13                                     ClubHitachiGym       [POINT]
# 14                                     ClubHitachiGym       [POINT]
# 15                            CrystallineSoundHealing       [POINT]
# 16                            CrystallineSoundHealing       [POINT]
# 17                            CrystallineSoundHealing       [POINT]
# 18                                        HotJavaToGo       [POINT]
# 19                                        HotJavaToGo       [POINT]
# 20                                        HotJavaToGo       [POINT]
# 21                                 IntelSantaClaraSC2       [POINT]
# 22                                 IntelSantaClaraSC2       [POINT]
# 23                                 IntelSantaClaraSC2       [POINT]
# 24  KineticWellnessCenterDrGeorgeChiropracticCorpo...       [POINT]
# 25  KineticWellnessCenterDrGeorgeChiropracticCorpo...       [POINT]
# 26  KineticWellnessCenterDrGeorgeChiropracticCorpo...       [POINT]
# 27                                          LucasHall       [POINT]
# 28                                          LucasHall       [POINT]
# 29                                          LucasHall       [POINT]
# 30                                     MillerNetworks       [POINT]
# 31                                     MillerNetworks       [POINT]
# 32                                     MillerNetworks       [POINT]
# 33                         MultitestElectronicSystems       [POINT]
# 34                         MultitestElectronicSystems       [POINT]
# 35                         MultitestElectronicSystems       [POINT]
# 36                                 OCZTechnologyGroup       [POINT]
# 37                                 OCZTechnologyGroup       [POINT]
# 38                                 OCZTechnologyGroup       [POINT]
# 39                          PeakTechnologyEnterprises       [POINT]
# 40                          PeakTechnologyEnterprises       [POINT]
# 41                          PeakTechnologyEnterprises       [POINT]
# 42                               PrimetimeMartialArts       [POINT]
# 43                               PrimetimeMartialArts       [POINT]
# 44                               PrimetimeMartialArts       [POINT]
# 45                                      SALClassrooms       [POINT]
# 46                                      SALClassrooms       [POINT]
# 47                                      SALClassrooms       [POINT]
# 48   SYNQMINEBusinessIntelligenceOutsourceCFOServices       [POINT]
# 49   SYNQMINEBusinessIntelligenceOutsourceCFOServices       [POINT]
# 50   SYNQMINEBusinessIntelligenceOutsourceCFOServices       [POINT]
# 51                      SkipsTireAutoCenterCottleRoad       [POINT]
# 52                      SkipsTireAutoCenterCottleRoad       [POINT]
# 53                      SkipsTireAutoCenterCottleRoad       [POINT]
# 54                                 VictoryMartialArts       [POINT]
# 55                                 VictoryMartialArts       [POINT]
# 56                                 VictoryMartialArts       [POINT]
# 57              WatermarkMedicalAnimationIllustration       [POINT]
# 58              WatermarkMedicalAnimationIllustration       [POINT]
# 59              WatermarkMedicalAnimationIllustration       [POINT]
#
#    relationship_type                                        node_name_2  \
# 0           distance                                 OCZTechnologyGroup
# 1           distance                               PrimetimeMartialArts
# 2           distance                      SkipsTireAutoCenterCottleRoad
# 3           distance                  ChildrensDiscoveryMuseumofSanJose
# 4           distance                                      SALClassrooms
# 5           distance   SYNQMINEBusinessIntelligenceOutsourceCFOServices
# 6           distance                                     ClubHitachiGym
# 7           distance                         MultitestElectronicSystems
# 8           distance   SYNQMINEBusinessIntelligenceOutsourceCFOServices
# 9           distance                                         BloomFresh
# 10          distance                                          LucasHall
# 11          distance                                      SALClassrooms
# 12          distance                                 IntelSantaClaraSC2
# 13          distance                                          LucasHall
# 14          distance                         MultitestElectronicSystems
# 15          distance                                          LucasHall
# 16          distance                                 VictoryMartialArts
# 17          distance              WatermarkMedicalAnimationIllustration
# 18          distance  KineticWellnessCenterDrGeorgeChiropracticCorpo...
# 19          distance                                 OCZTechnologyGroup
# 20          distance                          PeakTechnologyEnterprises
# 21          distance                                     ClubHitachiGym
# 22          distance                         MultitestElectronicSystems
# 23          distance              WatermarkMedicalAnimationIllustration
# 24          distance                                 OCZTechnologyGroup
# 25          distance                          PeakTechnologyEnterprises
# 26          distance                               PrimetimeMartialArts
# 27          distance                                     ClubHitachiGym
# 28          distance                                 IntelSantaClaraSC2
# 29          distance                         MultitestElectronicSystems
# 30          distance                                        HotJavaToGo
# 31          distance  KineticWellnessCenterDrGeorgeChiropracticCorpo...
# 32          distance                          PeakTechnologyEnterprises
# 33          distance                                     ClubHitachiGym
# 34          distance                                 IntelSantaClaraSC2
# 35          distance              WatermarkMedicalAnimationIllustration
# 36          distance  KineticWellnessCenterDrGeorgeChiropracticCorpo...
# 37          distance                          PeakTechnologyEnterprises
# 38          distance                               PrimetimeMartialArts
# 39          distance  KineticWellnessCenterDrGeorgeChiropracticCorpo...
# 40          distance                                 OCZTechnologyGroup
# 41          distance                               PrimetimeMartialArts
# 42          distance                               BenefitBrowBarAtUlta
# 43          distance                                 OCZTechnologyGroup
# 44          distance                      SkipsTireAutoCenterCottleRoad
# 45          distance                                         BloomFresh
# 46          distance                  ChildrensDiscoveryMuseumofSanJose
# 47          distance                                          LucasHall
# 48          distance                     CaringNeighborsEnterprisesInc_
# 49          distance                                     ClubHitachiGym
# 50          distance                         MultitestElectronicSystems
# 51          distance                               BenefitBrowBarAtUlta
# 52          distance                                 OCZTechnologyGroup
# 53          distance                               PrimetimeMartialArts
# 54          distance                               BenefitBrowBarAtUlta
# 55          distance                               PrimetimeMartialArts
# 56          distance                      SkipsTireAutoCenterCottleRoad
# 57          distance                                     ClubHitachiGym
# 58          distance                                 IntelSantaClaraSC2
# 59          distance                         MultitestElectronicSystems
#
#    node_2_labels
# 0        [POINT]
# 1        [POINT]
# 2        [POINT]
# 3        [POINT]
# 4        [POINT]
# 5        [POINT]
# 6        [POINT]
# 7        [POINT]
# 8        [POINT]
# 9        [POINT]
# 10       [POINT]
# 11       [POINT]
# 12       [POINT]
# 13       [POINT]
# 14       [POINT]
# 15       [POINT]
# 16       [POINT]
# 17       [POINT]
# 18       [POINT]
# 19       [POINT]
# 20       [POINT]
# 21       [POINT]
# 22       [POINT]
# 23       [POINT]
# 24       [POINT]
# 25       [POINT]
# 26       [POINT]
# 27       [POINT]
# 28       [POINT]
# 29       [POINT]
# 30       [POINT]
# 31       [POINT]
# 32       [POINT]
# 33       [POINT]
# 34       [POINT]
# 35       [POINT]
# 36       [POINT]
# 37       [POINT]
# 38       [POINT]
# 39       [POINT]
# 40       [POINT]
# 41       [POINT]
# 42       [POINT]
# 43       [POINT]
# 44       [POINT]
# 45       [POINT]
# 46       [POINT]
# 47       [POINT]
# 48       [POINT]
# 49       [POINT]
# 50       [POINT]
# 51       [POINT]
# 52       [POINT]
# 53       [POINT]
# 54       [POINT]
# 55       [POINT]
# 56       [POINT]
# 57       [POINT]
# 58       [POINT]
# 59       [POINT]
# -------------------------
#   Density: 0.3
# -------------------------

# %%
query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = "CALL gds.graph.project('ds_graph', 'POINT', {distance: {properties: 'distance'}})"
session.run(query)

# %%
query = """

CALL gds.betweenness.stream('ds_graph', {relationshipWeightProperty: 'distance'})
YIELD nodeId, score
RETURN gds.util.asNode(nodeId).name AS name, score as betweenness
ORDER BY betweenness DESC

"""

res = my_neo4j_run_query_pandas(query)

res
# Out:
#                                                  name  betweenness
# 0                                PrimetimeMartialArts         16.0
# 1                                           LucasHall         14.0
# 2                                  OCZTechnologyGroup         13.0
# 3                                      ClubHitachiGym          7.0
# 4                                  VictoryMartialArts          6.0
# 5                                  IntelSantaClaraSC2          5.0
# 6                   ChildrensDiscoveryMuseumofSanJose          5.0
# 7                                          BloomFresh          4.0
# 8   KineticWellnessCenterDrGeorgeChiropracticCorpo...          3.0
# 9    SYNQMINEBusinessIntelligenceOutsourceCFOServices          3.0
# 10                         MultitestElectronicSystems          2.0
# 11                          PeakTechnologyEnterprises          1.0
# 12                      SkipsTireAutoCenterCottleRoad          1.0
# 13              WatermarkMedicalAnimationIllustration          1.0
# 14                               BenefitBrowBarAtUlta          0.0
# 15                                        HotJavaToGo          0.0
# 16                                     MillerNetworks          0.0
# 17                            CrystallineSoundHealing          0.0
# 18                                      SALClassrooms          0.0
# 19                     CaringNeighborsEnterprisesInc_          0.0

# %%
res.iloc[0]
# Out:
# name           PrimetimeMartialArts
# betweenness                    16.0
# Name: 0, dtype: object

# %%
# my_neo4j_wipe_out_database()

# %% [markdown]
# We need to know the point in each network with the highest centrality

# %%
county_central = {}

for county in set(locations_df['county']):
    
    nodes, node_relations = get_nodes(county)
    
    node_relations = augment_node_relations(nodes, node_relations)
    
    create_query, transformed_names = generate_query(nodes, node_relations)
    
    my_create_connected_graph(create_query)
    
    query = "CALL gds.graph.drop('ds_graph', false)"
    session.run(query)

    query = "CALL gds.graph.project('ds_graph', 'POINT', {distance: {properties: 'distance'}})"
    session.run(query)
    
    query = """

    CALL gds.betweenness.stream('ds_graph', {relationshipWeightProperty: 'distance'})
    YIELD nodeId, score
    RETURN gds.util.asNode(nodeId).name AS name, score as betweenness
    ORDER BY betweenness DESC

    """    
    res = my_neo4j_run_query_pandas(query)
    
    # Augment res with matching coordinates
    
    coord = []
    
    for i in range(res.shape[0]):
        
        temp = locations_df[['coordinates']].loc[locations_df['name'] == transformed_names[res.iloc[i]['name']] ]
        
        coord.append(temp.iat[0,0])
    
    res['coordinates'] = coord
    
    file_name = f'{county} Betweeness Results'

    res.to_csv(file_name, sep='\t')
    
#     print(locations_df.loc[locations_df['name'] == transformed_names[res.iloc[0]['name']] ]['coordinates'].iloc[0])

    county_central[county] = (res.iloc[0]['name'], locations_df.loc[locations_df['name'] == transformed_names[res.iloc[0]['name']] ]['coordinates'].iloc[0] )
    
county_central
# Out:
# {'Santa Clara': ('PrimetimeMartialArts', '(37.236254, -121.805053)'),
#  'Contra Costa': ('NewhallCommunityPark', '(37.953737, -121.977269)'),
#  'San Mateo': ('ForensicLaboratoryofSanMateoCo_SheriffsOffice',
#   '(37.513253, -122.33258)'),
#  'Alameda': ('PhantomMotors', '(37.678241, -122.09081)'),
#  'San Francisco': ('OldWestWesternWear', '(37.754265, -122.418352)')}

# %%
# Initialze the various maps we will need ahead of time to save on computing

maps = {}

for county in set(locations_df['county']):
    maps[county] = ox.graph_from_place(f"{county}, California, USA", network_type="drive")
    
print("Done!")
# Out:
# Done!

# %%
# Declare arrays to keep track of each other node's closest BART Station

nearest_station_names = []
nearest_station_coordinates = []
nearest_distances = []

for i, county in enumerate(set(locations_df['county'])):
    
    temp_nearest_station_name = ""
    temp_nearest_station_coordinate = (0,0)
    temp_nearest_distance = 100000000
    
    origin_coordinates = county_central[county][1]
    location_name = county_central[county][0]
    
    G = maps[county]
    
    for j in range(bart_stations_df.shape[0]):
        
        destination_coordinates = bart_stations_df.iloc[j]['coordinates']
        
        orig = origin_coordinates.strip("()").split(", ")
        dest = destination_coordinates.strip("()").split(", ")
        
        orig = (float(orig[0]), float(orig[1]))
        dest = (float(dest[0]), float(dest[1]))
    
        try:
            
            route = tc.distance.shortest_path(G, orig, dest)
            
            distance = route[0]

            if distance != 0 and distance < temp_nearest_distance:

                temp_nearest_distance = distance
                temp_nearest_station_name = bart_stations_df.iloc[j]['name']
                temp_nearest_station_coordinate = dest

        except:
            pass
        
        clear_output(wait=True)
        print(f"{i + 1} out of {len(set(locations_df['county']))} counties | node {j + 1} | {j + 1}/{bart_stations_df.shape[0]} of  distances calculated")
        
    nearest_station_names.append([county, temp_nearest_station_name])
    nearest_station_coordinates.append(temp_nearest_station_coordinate)
    nearest_distances.append(temp_nearest_distance)
# Out:
# 5 out of 5 counties | node 18 | 18/18 of  distances calculated

# %%
nearest_station_names
# Out:
# [['Santa Clara', 'Santana Row BART Station'],
#  ['Contra Costa', 'Oak Grove BART Station'],
#  ['San Mateo', 'Lafayette BART Station'],
#  ['Alameda', 'Hayward BART Station'],
#  ['San Francisco', 'Glen Park BART Station']]

# %%
nearest_distances
# Out:
# [19841.352105753722,
#  6502.00362830697,
#  17035.596304528794,
#  1065.776602003451,
#  3025.406207696406]

# %%
nearest_station_coordinates
# Out:
# [(37.323154, -121.948811),
#  (37.943057, -122.029329),
#  (37.893161, -122.124925),
#  (37.669748, -122.087035),
#  (37.733119, -122.433797)]

# %% [markdown]
# Now we want to visualize the points in each county. There are some key features which must be present:
#
# - All nodes in the county
# - The central node must be a different color
# - The BART station must be a different color
# - The path from the BART Station to the central node must be clearly highlighted

# %%
# Lets start by initializing all maps

counties = ['San Francisco', 'Santa Clara', 'Contra Costa', 'Alameda', 'San Mateo']
coordinates = [[37.759344, -122.446452], [37.258336, -121.734320], [37.955321, -121.879418], 
               [37.674112, -121.971002], [37.466796, -122.391435]]

# Declare a Hash Table to keep track of the maps

folium_maps = {}

for i, county in enumerate(counties):
    folium_maps[county] = folium.Map(location=coordinates[i], tiles='openstreetmap', prefer_canvas=True)

# --------------------------------------------------------------------------------------------
    
# Auxiliary function for plotting points 

def plot_point(node, map_, station=False, station_name=""):
    
    
    if station == False:
        
        point = node['coordinates'].strip("()").split(", ")

        point = (float(point[0]), float(point[1]))
        
        folium.CircleMarker(location=[point[0], point[1]],
                            radius=2,
                            weight=5,
                           color='blue',
                           label = node['name']).add_to(map_)
        folium.map.Marker(location=[point[0], point[1]],
                      icon=DivIcon(
                          icon_size=(20,20),
                          icon_anchor=(5,14),
                          html=f'<div style="font-size: 7pt">%s</div>' % node['name'],
                      )
                     ).add_to(map_)
    else:
        
        point = str(node).strip("()").split(", ")

        point = (float(point[0]), float(point[1]))
        
        folium.CircleMarker(location=[point[0], point[1]],
                            radius=2,
                            weight=5,
                           color='red',
                           name=station_name).add_to(map_)
        folium.map.Marker(location=[point[0], point[1]],
                      icon=DivIcon(
                          icon_size=(20,20),
                          icon_anchor=(5,14),
                          html=f'<div style="font-size: 7pt">%s</div>' % station_name,
                      )
                     ).add_to(map_)

# Auxiliary function for plotting shortest paths

def plot_path(orig, dest, county, map_):
    
    orig = orig.strip("()").split(", ")
    orig = (float(orig[0]), float(orig[1]))
    
#     print(orig[0], dest)
    
    G = maps[county]
#     G = map_
    
    origin_node = ox.distance.nearest_nodes(G, X=orig[1], Y=orig[0])
    destination_node = ox.distance.nearest_nodes(G, X=dest[1], Y=dest[0])
    
    route = nx.shortest_path(G, origin_node, destination_node)
    
    map_ = ox.plot_route_folium(G, route, route_map=map_, weight=10)

# -------------------------------------------------------------------------------------------------------------
    
# Plot all features for all maps

# Plot Nodes 
for county in set(locations_df['county']):

    nodes, node_relations = get_nodes(county)
    
    for i in range(nodes.shape[0]):
              
        plot_point(nodes.iloc[i], folium_maps[county])

# Plot Routes From BART to Central Node
for county in set(locations_df['county']):
    
    index = 0
    
    for i, entry in enumerate(nearest_station_names):
        
        if entry[0] == county:
            index = i 
            break
            
    dest = nearest_station_coordinates[index]
    orig = county_central[county][1]
    
    plot_path(orig, dest, county, folium_maps[county])

# Plot BART Nodes
for i, entry in enumerate(nearest_station_names):
    
    county = entry[0]
    
    Station_Name = entry[1]
    
    orig = nearest_station_coordinates[i]
    
    plot_point(orig, folium_maps[county], station=True, station_name=Station_Name)

    folium_maps[county].fit_bounds(folium_maps[county].get_bounds())
 
    filepath = f'{county}_route_graph.html'
    folium_maps[county].save(filepath)

# %%
for i, county in enumerate(counties):
    
    print(county)
    display(folium_maps[county])
# Out:
# San Francisco
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb59dba9b50725d1cd9dcb4e7c1ff689 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb59dba9b50725d1cd9dcb4e7c1ff689&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb59dba9b50725d1cd9dcb4e7c1ff689 = L.map(
#                 &quot;map_fb59dba9b50725d1cd9dcb4e7c1ff689&quot;,
#                 {
#                     center: [37.759344, -122.446452],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaa161d9cbbe77ada25d92d2092da0a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eaa161d9cbbe77ada25d92d2092da0a5.addTo(map_fb59dba9b50725d1cd9dcb4e7c1ff689);
#
#
#             var circle_marker_bac2eb94b1705f3cb8edd6542c7a5580 = L.circleMarker(
#                 [37.783964, -122.395231],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fb59dba9b50725d1cd9dcb4e7c1ff689);
#
#
#             var marker_d4bf75baa0f6a2627a5ca8996a87026b = L.marker(
#                 [37.783964, -122.395231],
#                 {}
#             ).addTo(map_fb59dba9b50725d1cd9dcb4e7c1ff689);
#
#
#             var div_icon_e17392d9871ed398cdc68ec1afc4e666 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eSony Creative Center San Francisco\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_d4bf75baa0f6a2627a5ca8996a87026b.setIcon(div_icon_e17392d9871ed398cdc68ec1afc4e666);
#
#
#             var circle_marker_1a32b132fecd75770ddb9a9b2f139bfe = L.circleMarker(
#                 [37.727135, -122.450492],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fb59dba9b50725d1cd9dcb4e7c1ff689);
#
#
#             var marker_57e7b3683ea2c5554ba391a1ce67f0cd = L.marker(
#                 [37.727135, -122.450492],
#                 {}
#             ).addTo(map_fb59dba9b50725d1cd9dcb4e7c1ff689);
#
#
#             var div_icon_adedb9436e0575c4e4b8fa44cf316337 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eCity College: Visual Arts Building\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_57e7b3683ea2c5554ba391a1ce67f0cd.setIcon(div_icon_adedb9436e0575c4e4b8fa44cf316337);
#
#
#             var circle_marker_76b626314566d666c026e748650fd808 = L.circleMarker(
#                 [37.774491, -122.437967],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fb59dba9b50725d1cd9dcb4e7c1ff689);
#
#
#             var marker_a53caf6e9bf6d2bdad3924934b790395 = L.marker(
#                 [37.774491, -122.437967],
#                 {}
#             ).addTo(map_fb59dba9b50725d1cd9dcb4e7c1ff689);
#
#
#             var div_icon_552050d567775ea0bb6013e0183c3aa6 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003ePlant House by Rare Device\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_a53caf6e9bf6d2bdad3924934b790395.setIcon(div_icon_552050d567775ea0bb6013e0183c3aa6);
#
#
#             var circle_marker_9fc8c705536cef66ee891e3f5493faa1 = L.circleMarker(
#                 [37.763049, -122.445744],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quo
# Santa Clara
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ad364070498da69323d97752e6ec4b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ad364070498da69323d97752e6ec4b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ad364070498da69323d97752e6ec4b4 = L.map(
#                 &quot;map_7ad364070498da69323d97752e6ec4b4&quot;,
#                 {
#                     center: [37.258336, -121.73432],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b256e24f681ef806228988f9e0025f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7b256e24f681ef806228988f9e0025f6.addTo(map_7ad364070498da69323d97752e6ec4b4);
#
#
#             var circle_marker_d6ad29c358efc3dfa53e84928c984cbd = L.circleMarker(
#                 [37.244966, -121.889866],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_7ad364070498da69323d97752e6ec4b4);
#
#
#             var marker_2493b074fdd7f2fcb565516a56690a03 = L.marker(
#                 [37.244966, -121.889866],
#                 {}
#             ).addTo(map_7ad364070498da69323d97752e6ec4b4);
#
#
#             var div_icon_3bdb9d1c969b6a941e9eded383a25d06 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eVictory Martial Arts\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_2493b074fdd7f2fcb565516a56690a03.setIcon(div_icon_3bdb9d1c969b6a941e9eded383a25d06);
#
#
#             var circle_marker_7bd4f8a9bc1f4a326a466d99a63a2589 = L.circleMarker(
#                 [37.377044, -121.95603],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_7ad364070498da69323d97752e6ec4b4);
#
#
#             var marker_e523a533f362caed755ae75f0ff1e274 = L.marker(
#                 [37.377044, -121.95603],
#                 {}
#             ).addTo(map_7ad364070498da69323d97752e6ec4b4);
#
#
#             var div_icon_b885f4c2198a744b43735af979f5d3ea = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eMultitest Electronic Systems\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_e523a533f362caed755ae75f0ff1e274.setIcon(div_icon_b885f4c2198a744b43735af979f5d3ea);
#
#
#             var circle_marker_c1b406b0cf0e92c0501c802cc5180816 = L.circleMarker(
#                 [37.402767, -121.891175],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_7ad364070498da69323d97752e6ec4b4);
#
#
#             var marker_bcf24c148d6c5f6abbaf9c94d6f036e3 = L.marker(
#                 [37.402767, -121.891175],
#                 {}
#             ).addTo(map_7ad364070498da69323d97752e6ec4b4);
#
#
#             var div_icon_25df149b092b6543fba955ed14d88f67 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eSYNQMINE Business Intelligence \u0026 Outsource CFO Services\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_bcf24c148d6c5f6abbaf9c94d6f036e3.setIcon(div_icon_25df149b092b6543fba955ed14d88f67);
#
#
#             var circle_marker_ae8cf78e7761b3c209d2f480767ffb42 = L.circleMarker(
#                 [37.351107, -121.939733],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;das
# Contra Costa
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_718d75e1e96bd48d560613f453276160 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_718d75e1e96bd48d560613f453276160&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_718d75e1e96bd48d560613f453276160 = L.map(
#                 &quot;map_718d75e1e96bd48d560613f453276160&quot;,
#                 {
#                     center: [37.955321, -121.879418],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc94ee813ff9fa8f447e936a3806a154 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc94ee813ff9fa8f447e936a3806a154.addTo(map_718d75e1e96bd48d560613f453276160);
#
#
#             var circle_marker_9ec00e18ac2eaa2ab449c91d6bde80e6 = L.circleMarker(
#                 [38.011075, -121.878951],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_718d75e1e96bd48d560613f453276160);
#
#
#             var marker_866604220cc25d87c73b4fe9f64933c0 = L.marker(
#                 [38.011075, -121.878951],
#                 {}
#             ).addTo(map_718d75e1e96bd48d560613f453276160);
#
#
#             var div_icon_f4a28d0191bbbe6a09f33590a22b0b3b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eHospital Systems\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_866604220cc25d87c73b4fe9f64933c0.setIcon(div_icon_f4a28d0191bbbe6a09f33590a22b0b3b);
#
#
#             var circle_marker_e21f19acae0dd09b1b6059cb241a89e6 = L.circleMarker(
#                 [37.953737, -121.977269],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_718d75e1e96bd48d560613f453276160);
#
#
#             var marker_0983b5a03160eb3847ef01774371e4ef = L.marker(
#                 [37.953737, -121.977269],
#                 {}
#             ).addTo(map_718d75e1e96bd48d560613f453276160);
#
#
#             var div_icon_4b5d4419c6b7d29bd724dad8c6cb5b5e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eNewhall Community Park\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_0983b5a03160eb3847ef01774371e4ef.setIcon(div_icon_4b5d4419c6b7d29bd724dad8c6cb5b5e);
#
#
#             var circle_marker_a2f3aa06746d924a1ccb978d530036d3 = L.circleMarker(
#                 [37.971829, -121.862055],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_718d75e1e96bd48d560613f453276160);
#
#
#             var marker_d2427e57fb5eae39a1d12dbab934f28f = L.marker(
#                 [37.971829, -121.862055],
#                 {}
#             ).addTo(map_718d75e1e96bd48d560613f453276160);
#
#
#             var div_icon_b952734f0a971113576f9cf4c09cec87 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eBlack Diamond Mines Regional Preserve\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_d2427e57fb5eae39a1d12dbab934f28f.setIcon(div_icon_b952734f0a971113576f9cf4c09cec87);
#
#
#             var circle_marker_4b36af2a09981a0ed1ed40fd696298d3 = L.circleMarker(
#                 [38.007423, -121.887473],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fil
# Alameda
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83c7c22bd7f132391dbe1fd62019457f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83c7c22bd7f132391dbe1fd62019457f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83c7c22bd7f132391dbe1fd62019457f = L.map(
#                 &quot;map_83c7c22bd7f132391dbe1fd62019457f&quot;,
#                 {
#                     center: [37.674112, -121.971002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b79105265245ac26dbe9260a1ccb190d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b79105265245ac26dbe9260a1ccb190d.addTo(map_83c7c22bd7f132391dbe1fd62019457f);
#
#
#             var circle_marker_4284404ba915908b0353ea1232022003 = L.circleMarker(
#                 [37.695409, -122.077991],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_83c7c22bd7f132391dbe1fd62019457f);
#
#
#             var marker_67e7d04a448979883c75585f17f19f81 = L.marker(
#                 [37.695409, -122.077991],
#                 {}
#             ).addTo(map_83c7c22bd7f132391dbe1fd62019457f);
#
#
#             var div_icon_61b8d1f0bf548dc5658401c8c639aa25 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eBus Stop #50773/28-San Leandro Bart\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_67e7d04a448979883c75585f17f19f81.setIcon(div_icon_61b8d1f0bf548dc5658401c8c639aa25);
#
#
#             var circle_marker_9b2f8133f37d97e11eacc6f1b91fcb6d = L.circleMarker(
#                 [37.552155, -122.063208],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_83c7c22bd7f132391dbe1fd62019457f);
#
#
#             var marker_440eacf7dab937141cac07689a24eb74 = L.marker(
#                 [37.552155, -122.063208],
#                 {}
#             ).addTo(map_83c7c22bd7f132391dbe1fd62019457f);
#
#
#             var div_icon_a6ec033316c5c545ce1694268eaf62f6 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eLogitech\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_440eacf7dab937141cac07689a24eb74.setIcon(div_icon_a6ec033316c5c545ce1694268eaf62f6);
#
#
#             var circle_marker_b12e189603628a4050490d684b4d9748 = L.circleMarker(
#                 [37.708072, -121.924819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_83c7c22bd7f132391dbe1fd62019457f);
#
#
#             var marker_3b01034c5d7c2f633459193c3a145001 = L.marker(
#                 [37.708072, -121.924819],
#                 {}
#             ).addTo(map_83c7c22bd7f132391dbe1fd62019457f);
#
#
#             var div_icon_efcb622dda4400eb260f55f33f21016e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eSpeeDee Oil Change and Tune-Up\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_3b01034c5d7c2f633459193c3a145001.setIcon(div_icon_efcb622dda4400eb260f55f33f21016e);
#
#
#             var circle_marker_f6c57e19a25a078a0fffec4962d410c6 = L.circleMarker(
#                 [37.411732, -122.014626],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&
# San Mateo
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5893711ff7a7fb4cf648afc9e86d7e6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5893711ff7a7fb4cf648afc9e86d7e6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5893711ff7a7fb4cf648afc9e86d7e6b = L.map(
#                 &quot;map_5893711ff7a7fb4cf648afc9e86d7e6b&quot;,
#                 {
#                     center: [37.466796, -122.391435],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_009d6602b77a4fd3df9d454e8543e5e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_009d6602b77a4fd3df9d454e8543e5e1.addTo(map_5893711ff7a7fb4cf648afc9e86d7e6b);
#
#
#             var circle_marker_a9cb209bb9d1919edda39cf3977c4fc5 = L.circleMarker(
#                 [37.485814, -122.238715],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_5893711ff7a7fb4cf648afc9e86d7e6b);
#
#
#             var marker_720d4524f1a9a675da57e104430e34e6 = L.marker(
#                 [37.485814, -122.238715],
#                 {}
#             ).addTo(map_5893711ff7a7fb4cf648afc9e86d7e6b);
#
#
#             var div_icon_2920a29f1fd311ecfacae771f010122c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003eFr Dental Laboratory\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_720d4524f1a9a675da57e104430e34e6.setIcon(div_icon_2920a29f1fd311ecfacae771f010122c);
#
#
#             var circle_marker_6417e50723939e314f5a1e57bcde3de3 = L.circleMarker(
#                 [37.592423, -122.489007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_5893711ff7a7fb4cf648afc9e86d7e6b);
#
#
#             var marker_917f684c078565fea22afc0a9f03f9c1 = L.marker(
#                 [37.592423, -122.489007],
#                 {}
#             ).addTo(map_5893711ff7a7fb4cf648afc9e86d7e6b);
#
#
#             var div_icon_5a9514021880eea6d94d97a0111afc2c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003ePacifica Spindrift Players\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_917f684c078565fea22afc0a9f03f9c1.setIcon(div_icon_5a9514021880eea6d94d97a0111afc2c);
#
#
#             var circle_marker_a28df089738102342d06acf5ab596806 = L.circleMarker(
#                 [37.478609, -122.291883],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_5893711ff7a7fb4cf648afc9e86d7e6b);
#
#
#             var marker_fcb5ac26b8a42e5594bd15fdc4320d14 = L.marker(
#                 [37.478609, -122.291883],
#                 {}
#             ).addTo(map_5893711ff7a7fb4cf648afc9e86d7e6b);
#
#
#             var div_icon_8138061384668358ba5652780ccd4380 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 7pt\&quot;\u003ePulgas Ridge Open Space Preserve\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [5, 14], &quot;iconSize&quot;: [20, 20]});
#             marker_fcb5ac26b8a42e5594bd15fdc4320d14.setIcon(div_icon_8138061384668358ba5652780ccd4380);
#
#
#             var circle_marker_b13dcd107f6953b28ed8184c0459ede4 = L.circleMarker(
#                 [37.534532, -122.331311],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;
